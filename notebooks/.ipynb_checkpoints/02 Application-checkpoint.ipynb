# %% [markdown]
# # Application: Creating a Telco Mobility Index
#
# 1. Add total travel distance
# 2. Add radius of gyration
# 3. Add activity entropy

# %%
import os
os.chdir("../")

# %%
import random
import shapely
import pendulum
import numpy as np
import pandas as pd
pd.options.display.max_rows=200
from sds4gdsp.processor import convert_cel_to_point, calc_haversine_distance
from sds4gdsp.plotter import get_route_fig, load_images, plot_images
from IPython.display import HTML, display
from functools import reduce

# %% [markdown]
# Load, take a peek, and get a gist of the given datasets
#
# a. Fake Subscribers <br>
# b. Fake Cellsites <br>
# c. Fake Transactions

# %%
filepath_subscribers = "data/fake_subscribers.csv"
dtype = dict(
    gender="category",
    age=int,
    name=str,
    chi_indicator=bool,
    ewallet_user_indicator="category"
)
fake_subscribers = pd.read_csv(filepath_subscribers, dtype=dtype)
fake_subscribers.sample(5)
# Out:
#         sub_uid  gender  age             name  chi_indicator
# 21  glo-sub-022  female   45      Kayla Munoz          False  \
# 66  glo-sub-067    male   49  Steven Cantrell           True
# 93  glo-sub-094    male   20     Brian Fisher          False
# 3   glo-sub-004    male   32     Ronald Perez          False
# 12  glo-sub-013  female   70      Sherri Hart          False
#
#    ewallet_user_indicator
# 21                      N
# 66                      N
# 93                      Y
# 3                       Y
# 12                      Y

# %%
fake_subscribers.shape
# Out:
# (100, 6)

# %%
cat_cols = ["gender", "chi_indicator", "ewallet_user_indicator"]
fs_breakdown = fake_subscribers.groupby(cat_cols).size().reset_index(name="cnt")
fs_breakdown.assign(pcnt=fs_breakdown.cnt.div(len(fake_subscribers)).mul(100).round(2))
# Out:
#    gender  chi_indicator ewallet_user_indicator  cnt  pcnt
# 0  female          False                      N   14  14.0
# 1  female          False                      Y   12  12.0
# 2  female           True                      N   10  10.0
# 3  female           True                      Y   14  14.0
# 4    male          False                      N   12  12.0
# 5    male          False                      Y   17  17.0
# 6    male           True                      N   14  14.0
# 7    male           True                      Y    7   7.0

# %%
filepath_cellsites = "data/fake_cellsites.csv"
fake_cellsites = pd.read_csv(filepath_cellsites)
fake_cellsites.sample(5)
# Out:
#         cel_uid                          coords
# 60  glo-cel-061   POINT (121.0609937 14.515681)
# 68  glo-cel-069  POINT (121.0641371 14.5345597)
# 71  glo-cel-072  POINT (121.0652592 14.5075252)
# 96  glo-cel-097    POINT (121.08102 14.5242676)
# 76  glo-cel-077  POINT (121.0693679 14.5119416)

# %%
fake_cellsites.shape
# Out:
# (111, 2)

# %%
HTML('<img src="../docs/fake_cellsites.png" width="600" height="600"/>')
# Out:
# <img src="../docs/fake_cellsites.png" width="600" height="600"/>

# %%
filepath_transactions = "data/fake_transactions.csv"
fake_transactions = pd.read_csv(filepath_transactions)

# %%
fake_transactions.shape
# Out:
# (15090, 5)

# %%
min_date = pendulum.parse(fake_transactions.transaction_dt.min(), exact=True)
max_date = pendulum.parse(fake_transactions.transaction_dt.max(), exact=True)
period = pendulum.period(min_date, max_date)

# %%
sample_dt = str(random.sample(list(period), 1)[0])
filter_dt = fake_transactions.transaction_dt == sample_dt
sample_sub = fake_subscribers.sub_uid.sample(1).item()
filter_sub = fake_transactions.sub_uid == sample_sub
fake_transactions.loc[filter_sub&filter_dt]
# Out:
#              txn_uid      sub_uid      cel_uid transaction_dt  transaction_hr
# 13489  glo-txn-13490  glo-sub-090  glo-cel-100     2023-06-15               5
# 13490  glo-txn-13491  glo-sub-090  glo-cel-101     2023-06-15              13
# 13491  glo-txn-13492  glo-sub-090  glo-cel-090     2023-06-15              17

# %% [markdown]
# Create a helper function to help fetch subscriber trajectory

# %%
def get_sub_traj(
    sub: str,
    date: str,
    window: str,
    transactions: pd.DataFrame,
    cellsites: pd.DataFrame
):
    if window=="month":
        date_filter = transactions.transaction_dt.apply(lambda d: pendulum.parse(d, exact=True).start_of("month").to_date_string())==date
    elif window=="day":
        date_filter = transactions.transaction_dt==date
    sub_filter = transactions.sub_uid==sub
    transactions_red = transactions.loc[sub_filter&date_filter]
    transactions_red = transactions_red.merge(cellsites, on="cel_uid")
    return transactions_red.sort_values(by=["transaction_dt", "transaction_hr"], ascending=[1, 1])

# %%
get_sub_traj("glo-sub-001", "2023-06-01", "month", fake_transactions, fake_cellsites)
# Out:
#            txn_uid      sub_uid      cel_uid transaction_dt  transaction_hr
# 0    glo-txn-00001  glo-sub-001  glo-cel-053     2023-06-01               3  \
# 1    glo-txn-00002  glo-sub-001  glo-cel-044     2023-06-01              15
# 5    glo-txn-00003  glo-sub-001  glo-cel-035     2023-06-01              20
# 2    glo-txn-00004  glo-sub-001  glo-cel-044     2023-06-01              21
# 6    glo-txn-00005  glo-sub-001  glo-cel-035     2023-06-01              23
# 7    glo-txn-00006  glo-sub-001  glo-cel-035     2023-06-02               3
# 12   glo-txn-00007  glo-sub-001  glo-cel-039     2023-06-02               4
# 22   glo-txn-00008  glo-sub-001  glo-cel-040     2023-06-02               8
# 26   glo-txn-00009  glo-sub-001  glo-cel-049     2023-06-02              11
# 30   glo-txn-00010  glo-sub-001  glo-cel-051     2023-06-02              12
# 13   glo-txn-00011  glo-sub-001  glo-cel-039     2023-06-02              16
# 31   glo-txn-00012  glo-sub-001  glo-cel-051     2023-06-02              17
# 27   glo-txn-00013  glo-sub-001  glo-cel-049     2023-06-02              18
# 23   glo-txn-00014  glo-sub-001  glo-cel-040     2023-06-02              22
# 24   glo-txn-00015  glo-sub-001  glo-cel-040     2023-06-03               3
# 44   glo-txn-00016  glo-sub-001  glo-cel-036     2023-06-03               7
# 25   glo-txn-00017  glo-sub-001  glo-cel-040     2023-06-03              10
# 45   glo-txn-00018  glo-sub-001  glo-cel-036     2023-06-03              18
# 46   glo-txn-00019  glo-sub-001  glo-cel-036     2023-06-04               3
# 63   glo-txn-00020  glo-sub-001  glo-cel-027     2023-06-04               6
# 76   glo-txn-00021  glo-sub-001  glo-cel-021     2023-06-04              12
# 80   glo-txn-00022  glo-sub-001  glo-cel-030     2023-06-04              16
# 81   glo-txn-00023  glo-sub-001  glo-cel-030     2023-06-05               3
# 64   glo-txn-00024  glo-sub-001  glo-cel-027     2023-06-05               8
# 82   glo-txn-00025  glo-sub-001  glo-cel-030     2023-06-05              16
# 47   glo-txn-00026  glo-sub-001  glo-cel-036     2023-06-05              17
# 48   glo-txn-00027  glo-sub-001  glo-cel-036     2023-06-06               3
# 65   glo-txn-00028  glo-sub-001  glo-cel-027     2023-06-06               7
# 39   glo-txn-00112  glo-sub-001  glo-cel-051     2023-06-23              22
# 40   glo-txn-00113  glo-sub-001  glo-cel-051     2023-06-24               3
# 111  glo-txn-00114  glo-sub-001  glo-cel-056     2023-06-24               4
# 129  glo-txn-00115  glo-sub-001  glo-cel-064     2023-06-24               9
# 130  glo-txn-00116  glo-sub-001  glo-cel-064     2023-06-25               3
# 136  glo-txn-00117  glo-sub-001  glo-cel-070     2023-06-25               5
# 131  glo-txn-00118  glo-sub-001  glo-cel-064     2023-06-25               7
# 137  glo-txn-00119  glo-sub-001  glo-cel-070     2023-06-25               9
# 132  glo-txn-00120  glo-sub-001  glo-cel-064     2023-06-25              19
# 133  glo-txn-00121  glo-sub-001  glo-cel-064     2023-06-26               3
# 142  glo-txn-00122  glo-sub-001  glo-cel-066     2023-06-26               5
# 144  glo-txn-00123  glo-sub-001  glo-cel-072     2023-06-26               7
# 143  glo-txn-00124  glo-sub-001  glo-cel-066     2023-06-26               8
# 138  glo-txn-00125  glo-sub-001  glo-cel-070     2023-06-26              21
# 139  glo-txn-00126  glo-sub-001  glo-cel-070     2023-06-27               3
# 134  glo-txn-00127  glo-sub-001  glo-cel-064     2023-06-27               7
# 140  glo-txn-00128  glo-sub-001  glo-cel-070     2023-06-27              11
# 141  glo-txn-00129  glo-sub-001  glo-cel-070     2023-06-28               3
# 135  glo-txn-00130  glo-sub-001  glo-cel-064     2023-06-28               4
# 112  glo-txn-00131  glo-sub-001  glo-cel-056     2023-06-28               7
# 126  glo-txn-00132  glo-sub-001  glo-cel-046     2023-06-28              11
# 20   glo-txn-00133  glo-sub-001  glo-cel-039     2023-06-28              21
# 127  glo-txn-00134  glo-sub-001  glo-cel-046     2023-06-28              22
# 128  glo-txn-00135  glo-sub-001  glo-cel-046     2023-06-29               3
# 21   glo-txn-00136  glo-sub-001  glo-cel-039     2023-06-29               4
# 41   glo-txn-00137  glo-sub-001  glo-cel-051     2023-06-29              11
# 113  glo-txn-00138  glo-sub-001  glo-cel-056     2023-06-29              17
# 114  glo-txn-00139  glo-sub-001  glo-cel-056     2023-06-30               3
# 42   glo-txn-00140  glo-sub-001  glo-cel-051     2023-06-30               4
# 115  glo-txn-00141  glo-sub-001  glo-cel-056     2023-06-30               6
# 43   glo-txn-00142  glo-sub-001  glo-cel-051     2023-06-30               7
# 29   glo-txn-00143  glo-sub-001  glo-cel-049     2023-06-30              10
# 103  glo-txn-00144  glo-sub-001  glo-cel-057     2023-06-30              19
# 97   glo-txn-00145  glo-sub-001  glo-cel-043     2023-06-30              20
#
#                              coords
# 0    POINT (121.0581692 14.5056112)
# 1    POINT (121.0550896 14.5056935)
# 5    POINT (121.0520115 14.5087523)
# 2    POINT (121.0550896 14.5056935)
# 6    POINT (121.0520115 14.5087523)
# 7    POINT (121.0520115 14.5087523)
# 12   POINT (121.0536333 14.5133711)
# 22    POINT (121.054184 14.5167555)
# 26   POINT (121.0568161 14.5177119)
# 30   POINT (121.0572633 14.5141269)
# 13   POINT (121.0536333 14.5133711)
# 31   POINT (121.0572633 14.5141269)
# 27   POINT (121.0568161 14.5177119)
# 23    POINT (121.054184 14.5167555)
# 24    POINT (121.054184 14.5167555)
# 44     POINT (121.052231 14.519476)
# 25    POINT (121.054184 14.5167555)
# 45     POINT (121.052231 14.519476)
# 46     POINT (121.052231 14.519476)
# 63   POINT (121.0482758 14.5207167)
# 76   POINT (121.0461939 14.5245073)
# 80   POINT (121.0493484 14.5234169)
# 81   POINT (121.0493484 14.5234169)
# 64   POINT (121.0482758 14.5207167)
# 82   POINT (121.0493484 14.5234169)
# 47     POINT (121.052231 14.519476)
# 48     POINT (121.052231 14.519476)
# 65   POINT (121.0482758 14.5207167)
# 77   POINT (121.0461939 14.5245073)
# 66   POINT (121.0482758 14.5207167)
# 49     POINT (121.052231 14.519476)
# 50     POINT (121.052231 14.519476)
# 67   POINT (121.0482758 14.5207167)
# 51     POINT (121.052231 14.519476)
# 68   POINT (121.0482758 14.5207167)
# 83   POINT (121.0493484 14.5234169)
# 84   POINT (121.0493484 14.5234169)
# 52     POINT (121.052231 14.519476)
# 88   POINT (121.0548721 14.5216456)
# 98    POINT (121.059168 14.5199865)
# 99    POINT (121.059168 14.5199865)
# 89   POINT (121.0548721 14.5216456)
# 53     POINT (121.052231 14.519476)
# 69   POINT (121.0482758 14.5207167)
# 70   POINT (121.0482758 14.5207167)
# 85   POINT (121.0493484 14.5234169)
# 78   POINT (121.0461939 14.5245073)
# 79   POINT (121.0461939 14.5245073)
# 71   POINT (121.0482758 14.5207167)
# 54     POINT (121.052231 14.519476)
# 72   POINT (121.0482758 14.5207167)
# 86   POINT (121.0493484 14.5234169)
# 87   POINT (121.0493484 14.5234169)
# 55     POINT (121.052231 14.519476)
# 56     POINT (121.052231 14.519476)
# 90   POINT (121.0548721 14.5216456)
# 100   POINT (121.059168 14.5199865)
# 91   POINT (121.0548721 14.5216456)
# 101   POINT (121.059168 14.5199865)
# 92   POINT (121.0548721 14.5216456)
# 93   POINT (121.0548721 14.5216456)
# 57     POINT (121.052231 14.519476)
# 73   POINT (121.0482758 14.5207167)
# 58     POINT (121.052231 14.519476)
# 59     POINT (121.052231 14.519476)
# 74   POINT (121.0482758 14.5207167)
# 60     POINT (121.052231 14.519476)
# 94   POINT (121.0548721 14.5216456)
# 95   POINT (121.0548721 14.5216456)
# 61     POINT (121.052231 14.519476)
# 75   POINT (121.0482758 14.5207167)
# 62     POINT (121.052231 14.519476)
# 96   POINT (121.0548721 14.5216456)
# 102   POINT (121.059168 14.5199865)
# 104   POINT (121.0609937 14.515681)
# 105   POINT (121.0609937 14.515681)
# 106  POINT (121.0591257 14.5116111)
# 116  POINT (121.0560984 14.5100246)
# 107  POINT (121.0591257 14.5116111)
# 117  POINT (121.0560984 14.5100246)
# 8    POINT (121.0520115 14.5087523)
# 9    POINT (121.0520115 14.5087523)
# 3    POINT (121.0550896 14.5056935)
# 10   POINT (121.0520115 14.5087523)
# 4    POINT (121.0550896 14.5056935)
# 118  POINT (121.0560984 14.5100246)
# 119  POINT (121.0560984 14.5100246)
# 108  POINT (121.0591257 14.5116111)
# 32   POINT (121.0572633 14.5141269)
# 33   POINT (121.0572633 14.5141269)
# 14   POINT (121.0536333 14.5133711)
# 120  POINT (121.0560984 14.5100246)
# 15   POINT (121.0536333 14.5133711)
# 34   POINT (121.0572633 14.5141269)
# 109  POINT (121.0591257 14.5116111)
# 121  POINT (121.0560984 14.5100246)
# 122  POINT (121.0560984 14.5100246)
# 11   POINT (121.0520115 14.5087523)
# 16   POINT (121.0536333 14.5133711)
# 123  POINT (121.0560984 14.5100246)
# 17   POINT (121.0536333 14.5133711)
# 124  POINT (121.0560984 14.5100246)
# 125  POINT (121.0560984 14.5100246)
# 110  POINT (121.0591257 14.5116111)
# 35   POINT (121.0572633 14.5141269)
# 18   POINT (121.0536333 14.5133711)
# 36   POINT (121.0572633 14.5141269)
# 37   POINT (121.0572633 14.5141269)
# 28   POINT (121.0568161 14.5177119)
# 38   POINT (121.0572633 14.5141269)
# 19   POINT (121.0536333 14.5133711)
# 39   POINT (121.0572633 14.5141269)
# 40   POINT (121.0572633 14.5141269)
# 111  POINT (121.0591257 14.5116111)
# 129   POINT (121.0618839 14.512313)
# 130   POINT (121.0618839 14.512313)
# 136  POINT (121.0648755 14.5124658)
# 131   POINT (121.0618839 14.512313)
# 137  POINT (121.0648755 14.5124658)
# 132   POINT (121.0618839 14.512313)
# 133   POINT (121.0618839 14.512313)
# 142  POINT (121.0625398 14.5092016)
# 144  POINT (121.0652592 14.5075252)
# 143  POINT (121.0625398 14.5092016)
# 138  POINT (121.0648755 14.5124658)
# 139  POINT (121.0648755 14.5124658)
# 134   POINT (121.0618839 14.512313)
# 140  POINT (121.0648755 14.5124658)
# 141  POINT (121.0648755 14.5124658)
# 135   POINT (121.0618839 14.512313)
# 112  POINT (121.0591257 14.5116111)
# 126  POINT (121.0560984 14.5100246)
# 20   POINT (121.0536333 14.5133711)
# 127  POINT (121.0560984 14.5100246)
# 128  POINT (121.0560984 14.5100246)
# 21   POINT (121.0536333 14.5133711)
# 41   POINT (121.0572633 14.5141269)
# 113  POINT (121.0591257 14.5116111)
# 114  POINT (121.0591257 14.5116111)
# 42   POINT (121.0572633 14.5141269)
# 115  POINT (121.0591257 14.5116111)
# 43   POINT (121.0572633 14.5141269)
# 29   POINT (121.0568161 14.5177119)
# 103   POINT (121.059168 14.5199865)
# 97   POINT (121.0548721 14.5216456)

# %% [markdown]
# We'll use this scoring base moving forward

# %%
scoring_base = fake_subscribers.copy()

# %%
# for uniformity
date = "2023-06-01"
window = "month"

# %% [markdown]
# ## 1: Total Travel Distance
#
# PSEUDOCODE
#
# a. Get chronologically-sequenced coordinate data from `traj` <br>
# NOTE: Sort first if not yet done, using date and hour fields
#
# b. Make O-D coord pairs with from (a) with lag=1 <br>
# NOTE: This should consider all of the origin points in the specified time window, i.e. an O-D transaction that originated from end of month (say 2023-06-30) and ends on the start of another month (say 2023-07-01) should still be computed (for monthly mobility index)
#
# c. Compute for the haversine distance from the O-D pairs then apply map then reduce

# %% [markdown]
# Check total travel distance (in meters) for a sample sub

# %%
sub = fake_subscribers.sample(1).sub_uid.item()
traj = get_sub_traj(sub, date, window, fake_transactions, fake_cellsites)
traj.head()
# Out:
#          txn_uid      sub_uid      cel_uid transaction_dt  transaction_hr
# 0  glo-txn-12986  glo-sub-087  glo-cel-012     2023-06-01               4  \
# 4  glo-txn-12987  glo-sub-087  glo-cel-010     2023-06-01              16
# 5  glo-txn-12988  glo-sub-087  glo-cel-010     2023-06-02               4
# 6  glo-txn-12989  glo-sub-087  glo-cel-008     2023-06-02               9
# 1  glo-txn-12990  glo-sub-087  glo-cel-012     2023-06-02              11
#
#                            coords
# 0  POINT (121.0395857 14.5055214)
# 4  POINT (121.0364372 14.5051236)
# 5  POINT (121.0364372 14.5051236)
# 6  POINT (121.0343255 14.5079164)
# 1  POINT (121.0395857 14.5055214)

# %%
coords = traj.coords.tolist()
od_pairs = list(zip(coords, coords[1:])) # think lag-1 in SQL

# %%
od_pairs[:4] # check with the traj table above
# Out:
# [('POINT (121.0395857 14.5055214)', 'POINT (121.0364372 14.5051236)'),
#  ('POINT (121.0364372 14.5051236)', 'POINT (121.0364372 14.5051236)'),
#  ('POINT (121.0364372 14.5051236)', 'POINT (121.0343255 14.5079164)'),
#  ('POINT (121.0343255 14.5079164)', 'POINT (121.0395857 14.5055214)')]

# %%
total_travel_distance = reduce(
    lambda a, b: a + b,
    list(map(lambda p: calc_haversine_distance(*p), od_pairs))
)

# %%
# convert to kilometer
total_travel_distance / 1_000
# Out:
# 42.26096001611502

# %% [markdown]
# Apply `calc_total_travel_distance` to the scoring base

# %%
def calc_total_travel_distance(traj):
    coords = traj.coords.tolist()
    od_pairs = list(zip(coords, coords[1:]))
    total_travel_distance = reduce(
        lambda a, b: a + b,
        list(map(lambda p: calc_haversine_distance(*p), od_pairs))
    )
    return total_travel_distance

# %%
total_travel_distances = []
for sub in scoring_base.sub_uid.tolist():
    traj = get_sub_traj(sub, date, window, fake_transactions, fake_cellsites)
    total_travel_distance = calc_total_travel_distance(traj)
    total_travel_distances.append(total_travel_distance)

scoring_base["total_travel_distance"] = total_travel_distances

# %%
scoring_base.sample(5)
# Out:
#         sub_uid  gender  age               name  chi_indicator
# 4   glo-sub-005    male   41     Matthew Powers          False  \
# 76  glo-sub-077  female   58  Michelle Martinez          False
# 98  glo-sub-099  female   52     Jennifer Smith           True
# 68  glo-sub-069    male   51       Daryl Benson           True
# 66  glo-sub-067    male   49    Steven Cantrell           True
#
#    ewallet_user_indicator  total_travel_distance
# 4                       Y           63274.996577
# 76                      Y           64606.002388
# 98                      N           52402.969151
# 68                      N           44044.218653
# 66                      N           52810.103921

# %% [markdown]
# ## 2: Radius of Gyration
#
# In mobility analysis, the radius of gyration indicates the characteristic distance travelled by the agent (in our case, the telco mobile subscriber). This is computed using the given formula below:
#
# $RoG$ = $\sqrt{\frac{1}{n} \sum \limits_{i=1}^{n} {dist(CoM,coord_i)^2}}$
#
# $CoM$ = $\frac{1}{n} \sum \limits_{i=1}^{n} (lat_i, lng_i)$
#
# Where: <br>
# RoG is Radius of Gyration <br>
# CoM is Center of Mass

# %% [markdown]
# Check radius of gyration (in meters) for a sample sub

# %%
sub = fake_subscribers.sample(1).sub_uid.item()
traj = get_sub_traj(sub, date, window, fake_transactions, fake_cellsites)
traj.head()
# Out:
#           txn_uid      sub_uid      cel_uid transaction_dt  transaction_hr
# 0   glo-txn-03658  glo-sub-025  glo-cel-072     2023-06-01               2  \
# 2   glo-txn-03659  glo-sub-025  glo-cel-070     2023-06-01              17
# 7   glo-txn-03660  glo-sub-025  glo-cel-066     2023-06-01              19
# 8   glo-txn-03661  glo-sub-025  glo-cel-066     2023-06-02               2
# 10  glo-txn-03662  glo-sub-025  glo-cel-064     2023-06-02               5
#
#                             coords
# 0   POINT (121.0652592 14.5075252)
# 2   POINT (121.0648755 14.5124658)
# 7   POINT (121.0625398 14.5092016)
# 8   POINT (121.0625398 14.5092016)
# 10   POINT (121.0618839 14.512313)

# %%
coords = traj.coords.tolist()

# %%
mean_lat = np.mean([shapely.wkt.loads(coord).y for coord in coords])
mean_lng = np.mean([shapely.wkt.loads(coord).x for coord in coords])
com = shapely.geometry.Point(mean_lng, mean_lat).wkt

# %%
print(mean_lat, mean_lng, com)
# Out:
# 14.515467025874125 121.05932146363635 POINT (121.05932146363635 14.515467025874125)

# %%
# compute for the distances from center of mass to each of the individual points
pt_pairs = list(zip(coords, [com]*len(coords))) # points-to-centerofmass
radius_of_gyration = np.sqrt(
    reduce(
        lambda a, b: a + b,
        list(map(lambda p: calc_haversine_distance(*p)**2, pt_pairs))
    ) / len(coords)
)

# %%
radius_of_gyration
# Out:
# 767.8630664858462

# %% [markdown]
# Apply `calc_radius_of_gyration` to the scoring base

# %%
def calc_radius_of_gyration(traj):
    
    coords = traj.coords.tolist()
    
    # compute for the center of mass
    mean_lat = np.mean([shapely.wkt.loads(coord).y for coord in coords])
    mean_lng = np.mean([shapely.wkt.loads(coord).x for coord in coords])
    com = shapely.geometry.Point(mean_lng, mean_lat).wkt
    
    # compute for the distances from CoM to individual points
    pt_pairs = list(zip(coords, [com]*len(coords)))
    radius_of_gyration = np.sqrt(
        reduce(
            lambda a, b: a + b,
            list(map(lambda p: calc_haversine_distance(*p)**2, pt_pairs))
        ) / len(coords)
    )
    return radius_of_gyration

# %%
radius_of_gyrations = []
for sub in scoring_base.sub_uid.tolist():
    traj = get_sub_traj(sub, date, window, fake_transactions, fake_cellsites)
    radius_of_gyration = calc_radius_of_gyration(traj)
    radius_of_gyrations.append(radius_of_gyration)

scoring_base["radius_of_gyration"] = radius_of_gyrations

# %%
scoring_base.sample(5)
# Out:
#         sub_uid  gender  age                 name  chi_indicator
# 26  glo-sub-027    male   45   Andrew Christensen          False  \
# 77  glo-sub-078    male   25  Alexander Hernandez           True
# 73  glo-sub-074    male   59      Clayton Johnson          False
# 34  glo-sub-035  female   27       Brenda Sanders          False
# 58  glo-sub-059  female   19        Lindsay Smith          False
#
#    ewallet_user_indicator  total_travel_distance  radius_of_gyration
# 26                      N           62395.696200          689.413995
# 77                      N           44323.256892         1167.704551
# 73                      Y           57028.719385          975.776455
# 34                      Y           62819.231098         1656.060762
# 58                      N           45470.929201         1417.528702

# %% [markdown]
# ## 3: Activity Entropy
#
# if stay_proba is low, likely to have:
#
# - LOWER total_travel_distance <br>
# - LOWER radius_of_gyration <br>
# - LOWER activity_entropy

# %% [markdown]
# Check activity entropy for a sample sub trajectory

# %%
sub = fake_subscribers.sample(1).sub_uid.item()
traj = get_sub_traj(sub, date, window, fake_transactions, fake_cellsites)
traj.head()
# Out:
#           txn_uid      sub_uid      cel_uid transaction_dt  transaction_hr
# 0   glo-txn-13255  glo-sub-089  glo-cel-078     2023-06-01               0  \
# 10  glo-txn-13256  glo-sub-089  glo-cel-079     2023-06-01               2
# 23  glo-txn-13257  glo-sub-089  glo-cel-071     2023-06-01               4
# 11  glo-txn-13258  glo-sub-089  glo-cel-079     2023-06-01              11
# 1   glo-txn-13259  glo-sub-089  glo-cel-078     2023-06-01              12
#
#                             coords
# 0   POINT (121.0695979 14.5168694)
# 10  POINT (121.0697891 14.5198829)
# 23  POINT (121.0649933 14.5209928)
# 11  POINT (121.0697891 14.5198829)
# 1   POINT (121.0695979 14.5168694)

# %%
loc_hrs = traj[["cel_uid", "transaction_hr"]].values.tolist()
od_loc_hrs = list(zip(loc_hrs, loc_hrs[1:]))

# %%
cels = list(set(traj.cel_uid.tolist()))

# %%
loc_hr_counter = dict(zip(cels, [0]*len(cels))) # THIS IS THE HASHMAP
for od_loc_hr in od_loc_hrs:
    orig = od_loc_hr[0]
    dest = od_loc_hr[1]
    cel = orig[0]
    if dest[1] > orig[1]:
        time_elapsed = dest[1] - orig[1]
    elif dest[1] < orig[1]:
        # next time elapsed jumps to another day
        time_elapsed = 24 - abs(dest[1] - orig[1])
    loc_hr_counter[cel] = loc_hr_counter[cel] + time_elapsed #  # I UPDATED THE HASHMAP

# %%
loc_hr_counter
# Out:
# {'glo-cel-030': 9,
#  'glo-cel-043': 7,
#  'glo-cel-079': 44,
#  'glo-cel-083': 88,
#  'glo-cel-089': 54,
#  'glo-cel-056': 13,
#  'glo-cel-039': 25,
#  'glo-cel-086': 48,
#  'glo-cel-040': 31,
#  'glo-cel-049': 21,
#  'glo-cel-027': 59,
#  'glo-cel-071': 14,
#  'glo-cel-057': 13,
#  'glo-cel-072': 2,
#  'glo-cel-021': 2,
#  'glo-cel-077': 20,
#  'glo-cel-064': 20,
#  'glo-cel-070': 20,
#  'glo-cel-051': 9,
#  'glo-cel-078': 23,
#  'glo-cel-066': 28,
#  'glo-cel-084': 70,
#  'glo-cel-036': 38,
#  'glo-cel-091': 56}

# %%
traj # sanity check
# Out:
#            txn_uid      sub_uid      cel_uid transaction_dt  transaction_hr
# 0    glo-txn-13255  glo-sub-089  glo-cel-078     2023-06-01               0  \
# 10   glo-txn-13256  glo-sub-089  glo-cel-079     2023-06-01               2
# 23   glo-txn-13257  glo-sub-089  glo-cel-071     2023-06-01               4
# 11   glo-txn-13258  glo-sub-089  glo-cel-079     2023-06-01              11
# 1    glo-txn-13259  glo-sub-089  glo-cel-078     2023-06-01              12
# 12   glo-txn-13260  glo-sub-089  glo-cel-079     2023-06-01              14
# 2    glo-txn-13261  glo-sub-089  glo-cel-078     2023-06-01              17
# 13   glo-txn-13262  glo-sub-089  glo-cel-079     2023-06-01              18
# 14   glo-txn-13263  glo-sub-089  glo-cel-079     2023-06-02               0
# 24   glo-txn-13264  glo-sub-089  glo-cel-071     2023-06-02               5
# 3    glo-txn-13265  glo-sub-089  glo-cel-078     2023-06-02               6
# 28   glo-txn-13266  glo-sub-089  glo-cel-084     2023-06-02              10
# 15   glo-txn-13267  glo-sub-089  glo-cel-079     2023-06-02              17
# 25   glo-txn-13268  glo-sub-089  glo-cel-071     2023-06-02              21
# 26   glo-txn-13269  glo-sub-089  glo-cel-071     2023-06-03               0
# 16   glo-txn-13270  glo-sub-089  glo-cel-079     2023-06-03               2
# 4    glo-txn-13271  glo-sub-089  glo-cel-078     2023-06-03               7
# 17   glo-txn-13272  glo-sub-089  glo-cel-079     2023-06-03              10
# 29   glo-txn-13273  glo-sub-089  glo-cel-084     2023-06-03              11
# 18   glo-txn-13274  glo-sub-089  glo-cel-079     2023-06-03              19
# 5    glo-txn-13275  glo-sub-089  glo-cel-078     2023-06-03              20
# 30   glo-txn-13276  glo-sub-089  glo-cel-084     2023-06-03              23
# 31   glo-txn-13277  glo-sub-089  glo-cel-084     2023-06-04               0
# 129  glo-txn-13402  glo-sub-089  glo-cel-040     2023-06-27               0
# 118  glo-txn-13403  glo-sub-089  glo-cel-039     2023-06-27               1
# 114  glo-txn-13404  glo-sub-089  glo-cel-051     2023-06-27               3
# 155  glo-txn-13405  glo-sub-089  glo-cel-056     2023-06-27               8
# 157  glo-txn-13406  glo-sub-089  glo-cel-064     2023-06-27              14
# 101  glo-txn-13407  glo-sub-089  glo-cel-070     2023-06-27              15
# 158  glo-txn-13408  glo-sub-089  glo-cel-064     2023-06-27              21
# 164  glo-txn-13409  glo-sub-089  glo-cel-066     2023-06-27              23
# 165  glo-txn-13410  glo-sub-089  glo-cel-066     2023-06-28               0
# 159  glo-txn-13411  glo-sub-089  glo-cel-064     2023-06-28               8
# 166  glo-txn-13412  glo-sub-089  glo-cel-066     2023-06-28              11
# 102  glo-txn-13413  glo-sub-089  glo-cel-070     2023-06-28              18
# 160  glo-txn-13414  glo-sub-089  glo-cel-064     2023-06-28              21
# 161  glo-txn-13415  glo-sub-089  glo-cel-064     2023-06-29               0
# 156  glo-txn-13416  glo-sub-089  glo-cel-056     2023-06-29               3
# 162  glo-txn-13417  glo-sub-089  glo-cel-064     2023-06-29              10
# 167  glo-txn-13418  glo-sub-089  glo-cel-066     2023-06-29              16
# 163  glo-txn-13419  glo-sub-089  glo-cel-064     2023-06-29              17
# 168  glo-txn-13420  glo-sub-089  glo-cel-066     2023-06-29              19
# 169  glo-txn-13421  glo-sub-089  glo-cel-066     2023-06-30               0
# 103  glo-txn-13422  glo-sub-089  glo-cel-070     2023-06-30               4
# 170  glo-txn-13423  glo-sub-089  glo-cel-066     2023-06-30               5
# 171  glo-txn-13424  glo-sub-089  glo-cel-072     2023-06-30               7
# 104  glo-txn-13425  glo-sub-089  glo-cel-070     2023-06-30               9
# 99   glo-txn-13426  glo-sub-089  glo-cel-077     2023-06-30              18
#
#                              coords
# 0    POINT (121.0695979 14.5168694)
# 10   POINT (121.0697891 14.5198829)
# 23   POINT (121.0649933 14.5209928)
# 11   POINT (121.0697891 14.5198829)
# 1    POINT (121.0695979 14.5168694)
# 12   POINT (121.0697891 14.5198829)
# 2    POINT (121.0695979 14.5168694)
# 13   POINT (121.0697891 14.5198829)
# 14   POINT (121.0697891 14.5198829)
# 24   POINT (121.0649933 14.5209928)
# 3    POINT (121.0695979 14.5168694)
# 28   POINT (121.0735688 14.5181671)
# 15   POINT (121.0697891 14.5198829)
# 25   POINT (121.0649933 14.5209928)
# 26   POINT (121.0649933 14.5209928)
# 16   POINT (121.0697891 14.5198829)
# 4    POINT (121.0695979 14.5168694)
# 17   POINT (121.0697891 14.5198829)
# 29   POINT (121.0735688 14.5181671)
# 18   POINT (121.0697891 14.5198829)
# 5    POINT (121.0695979 14.5168694)
# 30   POINT (121.0735688 14.5181671)
# 31   POINT (121.0735688 14.5181671)
# 43   POINT (121.0765315 14.5160907)
# 58   POINT (121.0778367 14.5185647)
# 69    POINT (121.0750697 14.521689)
# 59   POINT (121.0778367 14.5185647)
# 32   POINT (121.0735688 14.5181671)
# 70    POINT (121.0750697 14.521689)
# 60   POINT (121.0778367 14.5185647)
# 71    POINT (121.0750697 14.521689)
# 61   POINT (121.0778367 14.5185647)
# 62   POINT (121.0778367 14.5185647)
# 72    POINT (121.0750697 14.521689)
# 63   POINT (121.0778367 14.5185647)
# 44   POINT (121.0765315 14.5160907)
# 45   POINT (121.0765315 14.5160907)
# 80   POINT (121.0733576 14.5140961)
# 46   POINT (121.0765315 14.5160907)
# 47   POINT (121.0765315 14.5160907)
# 64   POINT (121.0778367 14.5185647)
# 48   POINT (121.0765315 14.5160907)
# 65   POINT (121.0778367 14.5185647)
# 73    POINT (121.0750697 14.521689)
# 74    POINT (121.0750697 14.521689)
# 33   POINT (121.0735688 14.5181671)
# 75    POINT (121.0750697 14.521689)
# 76    POINT (121.0750697 14.521689)
# 34   POINT (121.0735688 14.5181671)
# 49   POINT (121.0765315 14.5160907)
# 81   POINT (121.0733576 14.5140961)
# 94   POINT (121.0693679 14.5119416)
# 95   POINT (121.0693679 14.5119416)
# 100  POINT (121.0648755 14.5124658)
# 96   POINT (121.0693679 14.5119416)
# 6    POINT (121.0695979 14.5168694)
# 82   POINT (121.0733576 14.5140961)
# 50   POINT (121.0765315 14.5160907)
# 83   POINT (121.0733576 14.5140961)
# 84   POINT (121.0733576 14.5140961)
# 51   POINT (121.0765315 14.5160907)
# 85   POINT (121.0733576 14.5140961)
# 52   POINT (121.0765315 14.5160907)
# 66   POINT (121.0778367 14.5185647)
# 67   POINT (121.0778367 14.5185647)
# 53   POINT (121.0765315 14.5160907)
# 35   POINT (121.0735688 14.5181671)
# 77    POINT (121.0750697 14.521689)
# 78    POINT (121.0750697 14.521689)
# 36   POINT (121.0735688 14.5181671)
# 79    POINT (121.0750697 14.521689)
# 68   POINT (121.0778367 14.5185647)
# 54   POINT (121.0765315 14.5160907)
# 86   POINT (121.0733576 14.5140961)
# 87   POINT (121.0733576 14.5140961)
# 37   POINT (121.0735688 14.5181671)
# 55   POINT (121.0765315 14.5160907)
# 88   POINT (121.0733576 14.5140961)
# 89   POINT (121.0733576 14.5140961)
# 56   POINT (121.0765315 14.5160907)
# 90   POINT (121.0733576 14.5140961)
# 57   POINT (121.0765315 14.5160907)
# 91   POINT (121.0733576 14.5140961)
# 97   POINT (121.0693679 14.5119416)
# 7    POINT (121.0695979 14.5168694)
# 92   POINT (121.0733576 14.5140961)
# 93   POINT (121.0733576 14.5140961)
# 98   POINT (121.0693679 14.5119416)
# 8    POINT (121.0695979 14.5168694)
# 38   POINT (121.0735688 14.5181671)
# 39   POINT (121.0735688 14.5181671)
# 19   POINT (121.0697891 14.5198829)
# 9    POINT (121.0695979 14.5168694)
# 20   POINT (121.0697891 14.5198829)
# 40   POINT (121.0735688 14.5181671)
# 21   POINT (121.0697891 14.5198829)
# 41   POINT (121.0735688 14.5181671)
# 42   POINT (121.0735688 14.5181671)
# 22   POINT (121.0697891 14.5198829)
# 27   POINT (121.0649933 14.5209928)
# 105   POINT (121.059168 14.5199865)
# 108  POINT (121.0568161 14.5177119)
# 113  POINT (121.0572633 14.5141269)
# 115  POINT (121.0536333 14.5133711)
# 116  POINT (121.0536333 14.5133711)
# 119   POINT (121.054184 14.5167555)
# 109  POINT (121.0568161 14.5177119)
# 120   POINT (121.054184 14.5167555)
# 121   POINT (121.054184 14.5167555)
# 130    POINT (121.052231 14.519476)
# 140  POINT (121.0548721 14.5216456)
# 106   POINT (121.059168 14.5199865)
# 110  POINT (121.0568161 14.5177119)
# 107   POINT (121.059168 14.5199865)
# 111  POINT (121.0568161 14.5177119)
# 122   POINT (121.054184 14.5167555)
# 123   POINT (121.054184 14.5167555)
# 131    POINT (121.052231 14.519476)
# 124   POINT (121.054184 14.5167555)
# 117  POINT (121.0536333 14.5133711)
# 125   POINT (121.054184 14.5167555)
# 126   POINT (121.054184 14.5167555)
# 112  POINT (121.0568161 14.5177119)
# 127   POINT (121.054184 14.5167555)
# 132    POINT (121.052231 14.519476)
# 141  POINT (121.0548721 14.5216456)
# 133    POINT (121.052231 14.519476)
# 142  POINT (121.0482758 14.5207167)
# 150  POINT (121.0493484 14.5234169)
# 134    POINT (121.052231 14.519476)
# 135    POINT (121.052231 14.519476)
# 143  POINT (121.0482758 14.5207167)
# 136    POINT (121.052231 14.519476)
# 144  POINT (121.0482758 14.5207167)
# 153  POINT (121.0461939 14.5245073)
# 145  POINT (121.0482758 14.5207167)
# 154  POINT (121.0461939 14.5245073)
# 146  POINT (121.0482758 14.5207167)
# 151  POINT (121.0493484 14.5234169)
# 152  POINT (121.0493484 14.5234169)
# 147  POINT (121.0482758 14.5207167)
# 137    POINT (121.052231 14.519476)
# 138    POINT (121.052231 14.519476)
# 148  POINT (121.0482758 14.5207167)
# 149  POINT (121.0482758 14.5207167)
# 139    POINT (121.052231 14.519476)
# 128   POINT (121.054184 14.5167555)
# 129   POINT (121.054184 14.5167555)
# 118  POINT (121.0536333 14.5133711)
# 114  POINT (121.0572633 14.5141269)
# 155  POINT (121.0591257 14.5116111)
# 157   POINT (121.0618839 14.512313)
# 101  POINT (121.0648755 14.5124658)
# 158   POINT (121.0618839 14.512313)
# 164  POINT (121.0625398 14.5092016)
# 165  POINT (121.0625398 14.5092016)
# 159   POINT (121.0618839 14.512313)
# 166  POINT (121.0625398 14.5092016)
# 102  POINT (121.0648755 14.5124658)
# 160   POINT (121.0618839 14.512313)
# 161   POINT (121.0618839 14.512313)
# 156  POINT (121.0591257 14.5116111)
# 162   POINT (121.0618839 14.512313)
# 167  POINT (121.0625398 14.5092016)
# 163   POINT (121.0618839 14.512313)
# 168  POINT (121.0625398 14.5092016)
# 169  POINT (121.0625398 14.5092016)
# 103  POINT (121.0648755 14.5124658)
# 170  POINT (121.0625398 14.5092016)
# 171  POINT (121.0652592 14.5075252)
# 104  POINT (121.0648755 14.5124658)
# 99   POINT (121.0693679 14.5119416)

# %%
proba_per_site = [hr_spent/sum(loc_hr_counter.values()) for hr_spent in loc_hr_counter.values()]

# %%
np.sum(proba_per_site)
# Out:
# 0.9999999999999999

# %%
activity_entropy = reduce(lambda a, b: a + b, map(lambda p: p*np.log10(1/p), proba_per_site))
print(activity_entropy)

# TODO: add logbase2
# try float dtype
# Out:
# 1.260705989277877

# %% [markdown]
# Apply `calc_activity_entropy` to the scoring base

# %%
def calc_activity_entropy(traj):
    
    try:
    
        loc_hrs = traj[["cel_uid", "transaction_hr"]].values.tolist()
        od_loc_hrs = list(zip(loc_hrs, loc_hrs[1:]))    
        cels = list(set(traj.cel_uid.tolist()))

        loc_hr_counter = dict(zip(cels, [0]*len(cels)))
        for od_loc_hr in od_loc_hrs:
            orig = od_loc_hr[0]
            dest = od_loc_hr[1]
            cel = orig[0]
            if dest[1] > orig[1]:
                time_elapsed = dest[1] - orig[1]
            elif dest[1] < orig[1]:
                # next time elapsed jumps to another day
                time_elapsed = 24 - abs(dest[1] - orig[1])
            loc_hr_counter[cel] = loc_hr_counter[cel] + time_elapsed

        # time spent on a single site vs time spent on all sites
        proba_per_site = [hr_spent/sum(loc_hr_counter.values()) for hr_spent in loc_hr_counter.values()]

        # sum(p * log(1/p)) where p is the proba for a single site
        activity_entropy = reduce(lambda a, b: a + b, map(lambda p: p*np.log10(1/p), proba_per_site))
    
        return activity_entropy
    
    except:
        
        return None

# %%
activity_entropys = []
for sub in scoring_base.sub_uid.tolist():
    traj = get_sub_traj(sub, date, window, fake_transactions, fake_cellsites)
    activity_entropy = calc_activity_entropy(traj)
    activity_entropys.append(activity_entropy)

scoring_base["activity_entropy"] = activity_entropys

# %% [markdown]
# 1. Scaling and remove the extremes

# %%
scoring_base.sample(5)
# Out:
#         sub_uid  gender  age                  name  chi_indicator
# 68  glo-sub-069    male   51          Daryl Benson           True  \
# 61  glo-sub-062  female   25       Stephanie Brady          False
# 87  glo-sub-088    male   21        Robert Bonilla          False
# 50  glo-sub-051  female   26  Mrs. Angela Reynolds          False
# 40  glo-sub-041  female   28         Carrie Wilson          False
#
#    ewallet_user_indicator  total_travel_distance  radius_of_gyration
# 68                      N           44044.218653         1055.217779  \
# 61                      Y           59114.871368         1062.212106
# 87                      N           40462.205640          828.557917
# 50                      N           38696.419193          867.903009
# 40                      Y           59351.076197         1173.828911
#
#     activity_entropy
# 68          1.295829
# 61          1.197811
# 87          1.211285
# 50          1.022761
# 40               NaN

# %% [markdown]
# TODO:
# 1. Make your own Mobility Index: HIGH-MID-LOW

# %% [markdown]
# ## RESULTS QA

# %%
scoring_base.total_travel_distance.describe().iloc[1:]
# Out:
# mean    55380.537901
# std      8653.141024
# min     38696.419193
# 25%     48476.164470
# 50%     54966.624566
# 75%     61732.564398
# max     80514.160201
# Name: total_travel_distance, dtype: float64

# %%
scoring_base.radius_of_gyration.describe().iloc[1:]
# Out:
# mean    1177.029710
# std      418.323945
# min      416.630638
# 25%      894.470166
# 50%     1090.858198
# 75%     1451.703190
# max     2308.794978
# Name: radius_of_gyration, dtype: float64

# %%
scoring_base.activity_entropy.describe().iloc[1:]
# Out:
# mean    1.216752
# std     0.160739
# min     0.754688
# 25%     1.128494
# 50%     1.229519
# 75%     1.329898
# max     1.534969
# Name: activity_entropy, dtype: float64

# %%
sub = fake_subscribers.sample(1).sub_uid.item()
traj = get_sub_traj(sub, date, window, fake_transactions, fake_cellsites)

# %%
traj.head()
# Out:
#           txn_uid      sub_uid      cel_uid transaction_dt  transaction_hr
# 0   glo-txn-00628  glo-sub-005  glo-cel-028     2023-06-01               0  \
# 6   glo-txn-00629  glo-sub-005  glo-cel-015     2023-06-01               2
# 8   glo-txn-00630  glo-sub-005  glo-cel-026     2023-06-01               3
# 19  glo-txn-00631  glo-sub-005  glo-cel-033     2023-06-01               5
# 30  glo-txn-00632  glo-sub-005  glo-cel-031     2023-06-01               6
#
#                             coords
# 0    POINT (121.0485358 14.494388)
# 6   POINT (121.0424143 14.4939573)
# 8   POINT (121.0480144 14.4988026)
# 19   POINT (121.050346 14.4970216)
# 30  POINT (121.0496008 14.5017326)

# %%
calc_activity_entropy(traj)
# Out:
# 1.3204924461567358

# %%
calc_radius_of_gyration(traj)
# Out:
# 1177.950286913251

# %%
calc_total_travel_distance(traj)
# Out:
# 63274.996577205566

# %% [markdown]
# ## PENDING ITEMS

# %% [markdown]
# 1. Redo the fake data simulation, make stay proba variable instead of fixed
# 2. Add visuals on total travel distance, radius of gyration, activity entropy
# 3. Finish lecture part 1, grammar of spatial data science

# %% [markdown]
# ## ARCHIVE

# %%
def get_route_fig(r):
    fig, ax = plt.subplots(1, 1)
    gpd.GeoSeries(r).plot(ax=ax, linewidth=5, zorder=1)
    orig = shapely.geometry.Point([r.xy[0][0], r.xy[1][0]])
    dest = shapely.geometry.Point([r.xy[0][-1], r.xy[1][-1]])
    gpd.GeoSeries(orig).plot(ax=ax, color="red", markersize=250, zorder=2, alpha=0.8)
    gpd.GeoSeries(dest).plot(ax=ax, color="green", markersize=250, zorder=2, alpha=0.8)
    plt.axis("off")
    ax.ticklabel_format(useOffset=False)
    plt.close()
    return fig

import os
import shapely
import geopandas as gpd
import matplotlib.pyplot as plt
from PIL import Image
import shutil

# %%
# day in a life of a sub
d = fake_transactions.copy()
sample_sub = d.sample(1).sub_id.item()
d = d.loc[d.sub_id==sample_sub]
days = d.transaction_dt.unique().tolist()
route_figs = []
for sample_day in days:
    sites = fake_transactions\
        .loc[fake_transactions.sub_id==sample_sub]\
        .loc[fake_transactions.transaction_dt==sample_day]\
        .cel_id.tolist()
    points = list(map(lambda z: convert_cel_to_point(z, fake_cellsites), sites))
    r = shapely.geometry.LineString(points)
    route_figs.append(get_route_fig(r))
os.mkdir("../sample/")
for idx, fig in enumerate(route_figs):
    fname = "../sample/{}_tmp.jpg".format(idx+1)
    fig.savefig(fname)
imgs = load_images("../sample")
plot_images(imgs)
shutil.rmtree("../sample")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [15], in <cell line: 7>()
#       7 for sample_day in days:
#       8     sites = fake_transactions\
#       9         .loc[fake_transactions.sub_id==sample_sub]\
#      10         .loc[fake_transactions.transaction_dt==sample_day]\
#      11         .cel_id.tolist()
# ---> 12     points = list(map(lambda z: convert_cel_to_point(z, fake_cellsites), sites))
#      13     r = shapely.geometry.LineString(points)
#      14     route_figs.append(get_route_fig(r))
#
# Input In [15], in <lambda>(z)
#       7 for sample_day in days:
#       8     sites = fake_transactions\
#       9         .loc[fake_transactions.sub_id==sample_sub]\
#      10         .loc[fake_transactions.transaction_dt==sample_day]\
#      11         .cel_id.tolist()
# ---> 12     points = list(map(lambda z: convert_cel_to_point(z, fake_cellsites), sites))
#      13     r = shapely.geometry.LineString(points)
#      14     route_figs.append(get_route_fig(r))
#
# File ~/Desktop/dev/aa/sds4gdsp/sds4gdsp/processor.py:21, in convert_cel_to_point(cel_id, ref)
#      19 def convert_cel_to_point(cel_id: str, ref: pd.DataFrame):
#      20     """Convert cellsite to shapely point."""
# ---> 21     coord = ref.loc[ref.uid==cel_id].coords.item()
#      22     point = loads(coord)
#      23     return point
#
# File ~/opt/anaconda3/envs/gdsenv/lib/python3.8/site-packages/pandas/core/generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'uid'
