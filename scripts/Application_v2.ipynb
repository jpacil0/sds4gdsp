# %%
import os
os.chdir("C:/Users/10012425/Desktop/sds4gdsp/")

# %%
import random
import shapely
import pendulum
import numpy as np
import pandas as pd
pd.options.display.max_rows=200
from sds4gdsp.processor import convert_cel_to_point, calc_haversine_distance
from sds4gdsp.plotter import get_route_fig, load_images, plot_images
from IPython.display import HTML, display
from functools import reduce

# %%
filepath_subscribers = "data/fake_subscribers.csv"
dtype = dict(
    gender="category",
    age=int,
    name=str,
    chi_indicator=bool,
    ewallet_user_indicator="category"
)
fake_subscribers = pd.read_csv(filepath_subscribers, dtype=dtype)
fake_subscribers.sample(5)
# Out:
#         sub_uid  gender  age           name  chi_indicator  \
# 45  glo-sub-046    male   24   Luis Jackson           True
# 59  glo-sub-060    male   42   Philip Lewis           True
# 68  glo-sub-069    male   51   Kevin Gibson           True
# 80  glo-sub-081  female   48   Jessica Wood           True
# 99  glo-sub-100  female   40  Kiara Salazar           True
#
#    ewallet_user_indicator
# 45                      Y
# 59                      N
# 68                      N
# 80                      Y
# 99                      N

# %%
fake_subscribers.shape
# Out:
# (100, 6)

# %%
cat_cols = ["gender", "chi_indicator", "ewallet_user_indicator"]
fs_breakdown = fake_subscribers.groupby(cat_cols).size().reset_index(name="cnt")
fs_breakdown.assign(pcnt=fs_breakdown.cnt.div(len(fake_subscribers)).mul(100).round(2))
# Out:
#    gender  chi_indicator ewallet_user_indicator  cnt  pcnt
# 0  female          False                      N   14  14.0
# 1  female          False                      Y   12  12.0
# 2  female           True                      N   10  10.0
# 3  female           True                      Y   14  14.0
# 4    male          False                      N   12  12.0
# 5    male          False                      Y   17  17.0
# 6    male           True                      N   14  14.0
# 7    male           True                      Y    7   7.0

# %%
filepath_cellsites = "data/fake_cellsites.csv"
fake_cellsites = pd.read_csv(filepath_cellsites)
fake_cellsites.sample(5)
# Out:
#          cel_uid                          coords
# 74   glo-cel-075  POINT (121.0683106 14.5054757)
# 108  glo-cel-109  POINT (121.0940274 14.5297068)
# 89   glo-cel-090  POINT (121.0770828 14.5317044)
# 84   glo-cel-085  POINT (121.0743555 14.5324571)
# 69   glo-cel-070  POINT (121.0648755 14.5124658)

# %%
fake_cellsites.shape
# Out:
# (111, 2)

# %%
HTML('<img src="../docs/fake_cellsites.png" width="600" height="600"/>')
# Out:
# <img src="../docs/fake_cellsites.png" width="600" height="600"/>

# %%
filepath_transactions = "data/fake_transactions.csv"
fake_transactions = pd.read_csv(filepath_transactions)

# %%
fake_transactions.shape
# Out:
# (15090, 5)

# %%
min_date = pendulum.parse(fake_transactions.transaction_dt.min(), exact=True)
max_date = pendulum.parse(fake_transactions.transaction_dt.max(), exact=True)
period = pendulum.period(min_date, max_date)

# %%
sample_dt = str(random.sample(list(period), 1)[0])
filter_dt = fake_transactions.transaction_dt == sample_dt
sample_sub = fake_subscribers.sub_uid.sample(1).item()
filter_sub = fake_transactions.sub_uid == sample_sub
fake_transactions.loc[filter_sub&filter_dt]
# Out:
#             txn_uid      sub_uid      cel_uid transaction_dt  transaction_hr
# 4868  glo-txn-04869  glo-sub-032  glo-cel-036     2023-06-23               4
# 4869  glo-txn-04870  glo-sub-032  glo-cel-040     2023-06-23               5
# 4870  glo-txn-04871  glo-sub-032  glo-cel-036     2023-06-23              13
# 4871  glo-txn-04872  glo-sub-032  glo-cel-040     2023-06-23              14
# 4872  glo-txn-04873  glo-sub-032  glo-cel-036     2023-06-23              16
# 4873  glo-txn-04874  glo-sub-032  glo-cel-027     2023-06-23              22

# %%
def get_sub_traj(
    sub: str,
    date: str,
    window: str,
    transactions: pd.DataFrame,
    cellsites: pd.DataFrame
):
    if window=="month":
        date_filter = transactions.transaction_dt.apply(lambda d: pendulum.parse(d, exact=True).start_of("month").to_date_string())==date
    elif window=="day":
        date_filter = transactions.transaction_dt==date
    sub_filter = transactions.sub_uid==sub
    transactions_red = transactions.loc[sub_filter&date_filter]
    transactions_red = transactions_red.merge(cellsites, on="cel_uid")
    return transactions_red.sort_values(by=["transaction_dt", "transaction_hr"], ascending=[1, 1])

# %%
get_sub_traj("glo-sub-001", "2023-06-01", "month", fake_transactions, fake_cellsites)
# Out:
#            txn_uid      sub_uid      cel_uid transaction_dt  transaction_hr  \
# 0    glo-txn-00001  glo-sub-001  glo-cel-082     2023-06-01               3
# 5    glo-txn-00002  glo-sub-001  glo-cel-086     2023-06-01              15
# 11   glo-txn-00003  glo-sub-001  glo-cel-084     2023-06-01              20
# 6    glo-txn-00004  glo-sub-001  glo-cel-086     2023-06-01              21
# 12   glo-txn-00005  glo-sub-001  glo-cel-084     2023-06-01              23
# 13   glo-txn-00006  glo-sub-001  glo-cel-084     2023-06-02               3
# 17   glo-txn-00007  glo-sub-001  glo-cel-089     2023-06-02               4
# 20   glo-txn-00008  glo-sub-001  glo-cel-083     2023-06-02               8
# 23   glo-txn-00009  glo-sub-001  glo-cel-077     2023-06-02              11
# 21   glo-txn-00010  glo-sub-001  glo-cel-083     2023-06-02              12
# 18   glo-txn-00011  glo-sub-001  glo-cel-089     2023-06-02              16
# 22   glo-txn-00012  glo-sub-001  glo-cel-083     2023-06-02              17
# 19   glo-txn-00013  glo-sub-001  glo-cel-089     2023-06-02              18
# 24   glo-txn-00014  glo-sub-001  glo-cel-091     2023-06-02              22
# 25   glo-txn-00015  glo-sub-001  glo-cel-091     2023-06-03               3
# 14   glo-txn-00016  glo-sub-001  glo-cel-084     2023-06-03               7
# 7    glo-txn-00017  glo-sub-001  glo-cel-086     2023-06-03              10
# 15   glo-txn-00018  glo-sub-001  glo-cel-084     2023-06-03              18
# 16   glo-txn-00019  glo-sub-001  glo-cel-084     2023-06-04               3
# 8    glo-txn-00020  glo-sub-001  glo-cel-086     2023-06-04               6
# 26   glo-txn-00021  glo-sub-001  glo-cel-091     2023-06-04              12
# 9    glo-txn-00022  glo-sub-001  glo-cel-086     2023-06-04              16
# 10   glo-txn-00023  glo-sub-001  glo-cel-086     2023-06-05               3
# 1    glo-txn-00024  glo-sub-001  glo-cel-082     2023-06-05               8
# 27   glo-txn-00025  glo-sub-001  glo-cel-088     2023-06-05              16
# 2    glo-txn-00026  glo-sub-001  glo-cel-082     2023-06-05              17
# 3    glo-txn-00027  glo-sub-001  glo-cel-082     2023-06-06               3
# 28   glo-txn-00028  glo-sub-001  glo-cel-088     2023-06-06               7
# 32   glo-txn-00029  glo-sub-001  glo-cel-090     2023-06-06              16
# 71   glo-txn-00113  glo-sub-001  glo-cel-106     2023-06-24               3
# 142  glo-txn-00114  glo-sub-001  glo-cel-107     2023-06-24               4
# 72   glo-txn-00115  glo-sub-001  glo-cel-106     2023-06-24               9
# 73   glo-txn-00116  glo-sub-001  glo-cel-106     2023-06-25               3
# 143  glo-txn-00117  glo-sub-001  glo-cel-107     2023-06-25               5
# 62   glo-txn-00118  glo-sub-001  glo-cel-103     2023-06-25               7
# 137  glo-txn-00119  glo-sub-001  glo-cel-096     2023-06-25               9
# 63   glo-txn-00120  glo-sub-001  glo-cel-103     2023-06-25              19
# 64   glo-txn-00121  glo-sub-001  glo-cel-103     2023-06-26               3
# 138  glo-txn-00122  glo-sub-001  glo-cel-096     2023-06-26               5
# 79   glo-txn-00123  glo-sub-001  glo-cel-092     2023-06-26               7
# 113  glo-txn-00124  glo-sub-001  glo-cel-087     2023-06-26               8
# 80   glo-txn-00125  glo-sub-001  glo-cel-092     2023-06-26              21
# 81   glo-txn-00126  glo-sub-001  glo-cel-092     2023-06-27               3
# 114  glo-txn-00127  glo-sub-001  glo-cel-087     2023-06-27               7
# 124  glo-txn-00128  glo-sub-001  glo-cel-095     2023-06-27              11
# 125  glo-txn-00129  glo-sub-001  glo-cel-095     2023-06-28               3
# 115  glo-txn-00130  glo-sub-001  glo-cel-087     2023-06-28               4
# 126  glo-txn-00131  glo-sub-001  glo-cel-095     2023-06-28               7
# 116  glo-txn-00132  glo-sub-001  glo-cel-087     2023-06-28              11
# 82   glo-txn-00133  glo-sub-001  glo-cel-092     2023-06-28              21
# 48   glo-txn-00134  glo-sub-001  glo-cel-100     2023-06-28              22
# 49   glo-txn-00135  glo-sub-001  glo-cel-100     2023-06-29               3
# 41   glo-txn-00136  glo-sub-001  glo-cel-101     2023-06-29               4
# 50   glo-txn-00137  glo-sub-001  glo-cel-100     2023-06-29              11
# 42   glo-txn-00138  glo-sub-001  glo-cel-101     2023-06-29              17
# 43   glo-txn-00139  glo-sub-001  glo-cel-101     2023-06-30               3
# 37   glo-txn-00140  glo-sub-001  glo-cel-090     2023-06-30               4
# 31   glo-txn-00141  glo-sub-001  glo-cel-088     2023-06-30               6
# 4    glo-txn-00142  glo-sub-001  glo-cel-082     2023-06-30               7
# 144  glo-txn-00143  glo-sub-001  glo-cel-076     2023-06-30              10
# 90   glo-txn-00144  glo-sub-001  glo-cel-080     2023-06-30              19
# 104  glo-txn-00145  glo-sub-001  glo-cel-073     2023-06-30              20
#
#                              coords
# 0    POINT (121.0732848 14.5244576)
# 5     POINT (121.0750697 14.521689)
# 11   POINT (121.0735688 14.5181671)
# 6     POINT (121.0750697 14.521689)
# 12   POINT (121.0735688 14.5181671)
# 13   POINT (121.0735688 14.5181671)
# 17   POINT (121.0765315 14.5160907)
# 20   POINT (121.0733576 14.5140961)
# 23   POINT (121.0693679 14.5119416)
# 21   POINT (121.0733576 14.5140961)
# 18   POINT (121.0765315 14.5160907)
# 22   POINT (121.0733576 14.5140961)
# 19   POINT (121.0765315 14.5160907)
# 24   POINT (121.0778367 14.5185647)
# 25   POINT (121.0778367 14.5185647)
# 14   POINT (121.0735688 14.5181671)
# 7     POINT (121.0750697 14.521689)
# 15   POINT (121.0735688 14.5181671)
# 16   POINT (121.0735688 14.5181671)
# 8     POINT (121.0750697 14.521689)
# 26   POINT (121.0778367 14.5185647)
# 9     POINT (121.0750697 14.521689)
# 10    POINT (121.0750697 14.521689)
# 1    POINT (121.0732848 14.5244576)
# 27     POINT (121.0753033 14.52743)
# 2    POINT (121.0732848 14.5244576)
# 3    POINT (121.0732848 14.5244576)
# 28     POINT (121.0753033 14.52743)
# 32   POINT (121.0770828 14.5317044)
# 38   POINT (121.0824987 14.5309274)
# 44   POINT (121.0821408 14.5359371)
# 45   POINT (121.0821408 14.5359371)
# 51   POINT (121.0843146 14.5417498)
# 65   POINT (121.0885482 14.5413748)
# 52   POINT (121.0843146 14.5417498)
# 74   POINT (121.0784464 14.5397507)
# 75   POINT (121.0784464 14.5397507)
# 46   POINT (121.0821408 14.5359371)
# 39   POINT (121.0824987 14.5309274)
# 33   POINT (121.0770828 14.5317044)
# 34   POINT (121.0770828 14.5317044)
# 40   POINT (121.0824987 14.5309274)
# 35   POINT (121.0770828 14.5317044)
# 29     POINT (121.0753033 14.52743)
# 30     POINT (121.0753033 14.52743)
# 36   POINT (121.0770828 14.5317044)
# 83   POINT (121.0743555 14.5324571)
# 84   POINT (121.0743555 14.5324571)
# 86   POINT (121.0709136 14.5320765)
# 85   POINT (121.0743555 14.5324571)
# 87   POINT (121.0709136 14.5320765)
# 91   POINT (121.0673779 14.5360046)
# 92   POINT (121.0673779 14.5360046)
# 97    POINT (121.067227 14.5314205)
# 98    POINT (121.067227 14.5314205)
# 93   POINT (121.0673779 14.5360046)
# 105  POINT (121.0641371 14.5345597)
# 94   POINT (121.0673779 14.5360046)
# 99    POINT (121.067227 14.5314205)
# 106  POINT (121.0641371 14.5345597)
# 107  POINT (121.0641371 14.5345597)
# 100   POINT (121.067227 14.5314205)
# 108  POINT (121.0641371 14.5345597)
# 101   POINT (121.067227 14.5314205)
# 102   POINT (121.067227 14.5314205)
# 95   POINT (121.0673779 14.5360046)
# 103   POINT (121.067227 14.5314205)
# 88   POINT (121.0709136 14.5320765)
# 89   POINT (121.0709136 14.5320765)
# 96   POINT (121.0673779 14.5360046)
# 109  POINT (121.0712832 14.5392728)
# 110  POINT (121.0751054 14.5445315)
# 117  POINT (121.0802442 14.5467116)
# 127  POINT (121.0789244 14.5493345)
# 118  POINT (121.0802442 14.5467116)
# 119  POINT (121.0802442 14.5467116)
# 111  POINT (121.0751054 14.5445315)
# 129  POINT (121.0804294 14.5420173)
# 76   POINT (121.0784464 14.5397507)
# 130  POINT (121.0804294 14.5420173)
# 53   POINT (121.0843146 14.5417498)
# 54   POINT (121.0843146 14.5417498)
# 131  POINT (121.0804294 14.5420173)
# 77   POINT (121.0784464 14.5397507)
# 132  POINT (121.0804294 14.5420173)
# 120  POINT (121.0802442 14.5467116)
# 121  POINT (121.0802442 14.5467116)
# 133  POINT (121.0804294 14.5420173)
# 122  POINT (121.0802442 14.5467116)
# 123  POINT (121.0802442 14.5467116)
# 128  POINT (121.0789244 14.5493345)
# 112  POINT (121.0751054 14.5445315)
# 78   POINT (121.0784464 14.5397507)
# 47   POINT (121.0821408 14.5359371)
# 55   POINT (121.0843146 14.5417498)
# 134  POINT (121.0804294 14.5420173)
# 135  POINT (121.0804294 14.5420173)
# 56   POINT (121.0843146 14.5417498)
# 66   POINT (121.0885482 14.5413748)
# 139  POINT (121.0897214 14.5382141)
# 67   POINT (121.0885482 14.5413748)
# 57   POINT (121.0843146 14.5417498)
# 58   POINT (121.0843146 14.5417498)
# 136  POINT (121.0804294 14.5420173)
# 59   POINT (121.0843146 14.5417498)
# 68   POINT (121.0885482 14.5413748)
# 140  POINT (121.0897214 14.5382141)
# 141  POINT (121.0897214 14.5382141)
# 60   POINT (121.0843146 14.5417498)
# 69   POINT (121.0885482 14.5413748)
# 61   POINT (121.0843146 14.5417498)
# 70   POINT (121.0885482 14.5413748)
# 71   POINT (121.0885482 14.5413748)
# 142  POINT (121.0897214 14.5382141)
# 72   POINT (121.0885482 14.5413748)
# 73   POINT (121.0885482 14.5413748)
# 143  POINT (121.0897214 14.5382141)
# 62   POINT (121.0843146 14.5417498)
# 137  POINT (121.0804294 14.5420173)
# 63   POINT (121.0843146 14.5417498)
# 64   POINT (121.0843146 14.5417498)
# 138  POINT (121.0804294 14.5420173)
# 79   POINT (121.0784464 14.5397507)
# 113  POINT (121.0751054 14.5445315)
# 80   POINT (121.0784464 14.5397507)
# 81   POINT (121.0784464 14.5397507)
# 114  POINT (121.0751054 14.5445315)
# 124  POINT (121.0802442 14.5467116)
# 125  POINT (121.0802442 14.5467116)
# 115  POINT (121.0751054 14.5445315)
# 126  POINT (121.0802442 14.5467116)
# 116  POINT (121.0751054 14.5445315)
# 82   POINT (121.0784464 14.5397507)
# 48   POINT (121.0821408 14.5359371)
# 49   POINT (121.0821408 14.5359371)
# 41   POINT (121.0824987 14.5309274)
# 50   POINT (121.0821408 14.5359371)
# 42   POINT (121.0824987 14.5309274)
# 43   POINT (121.0824987 14.5309274)
# 37   POINT (121.0770828 14.5317044)
# 31     POINT (121.0753033 14.52743)
# 4    POINT (121.0732848 14.5244576)
# 144  POINT (121.0690023 14.5264475)
# 90   POINT (121.0709136 14.5320765)
# 104   POINT (121.067227 14.5314205)

# %%
scoring_base = fake_subscribers.copy()

# %%
# for uniformity
date = "2023-06-01"
window = "month"

# %%
sub = fake_subscribers.sample(1).sub_uid.item()
traj = get_sub_traj(sub, date, window, fake_transactions, fake_cellsites)
traj.head()
# Out:
#           txn_uid      sub_uid      cel_uid transaction_dt  transaction_hr  \
# 0   glo-txn-10400  glo-sub-070  glo-cel-028     2023-06-01               0
# 6   glo-txn-10401  glo-sub-070  glo-cel-026     2023-06-01               5
# 15  glo-txn-10402  glo-sub-070  glo-cel-031     2023-06-01               7
# 7   glo-txn-10403  glo-sub-070  glo-cel-026     2023-06-01               9
# 1   glo-txn-10404  glo-sub-070  glo-cel-028     2023-06-01              12
#
#                             coords
# 0    POINT (121.0485358 14.494388)
# 6   POINT (121.0480144 14.4988026)
# 15  POINT (121.0496008 14.5017326)
# 7   POINT (121.0480144 14.4988026)
# 1    POINT (121.0485358 14.494388)

# %%
coords = traj.coords.tolist()
od_pairs = list(zip(coords, coords[1:])) # think lag-1 in SQL

# %%
od_pairs[:4] # check with the traj table above
# Out:
# [('POINT (121.0485358 14.494388)', 'POINT (121.0480144 14.4988026)'),
#  ('POINT (121.0480144 14.4988026)', 'POINT (121.0496008 14.5017326)'),
#  ('POINT (121.0496008 14.5017326)', 'POINT (121.0480144 14.4988026)'),
#  ('POINT (121.0480144 14.4988026)', 'POINT (121.0485358 14.494388)')]

# %%
total_travel_distance = reduce(
    lambda a, b: a + b,
    list(map(lambda p: calc_haversine_distance(*p), od_pairs))
)

# %%
# convert to kilometer
total_travel_distance / 1_000
# Out:
# 56.54259860729366

# %%
def calc_total_travel_distance(traj):
    coords = traj.coords.tolist()
    od_pairs = list(zip(coords, coords[1:]))
    total_travel_distance = reduce(
        lambda a, b: a + b,
        list(map(lambda p: calc_haversine_distance(*p), od_pairs))
    )
    return total_travel_distance

# %%
total_travel_distances = []
for sub in scoring_base.sub_uid.tolist():
    traj = get_sub_traj(sub, date, window, fake_transactions, fake_cellsites)
    total_travel_distance = calc_total_travel_distance(traj)
    total_travel_distances.append(total_travel_distance)

scoring_base["total_travel_distance"] = total_travel_distances

# %%
scoring_base.sample(5)
# Out:
#         sub_uid  gender  age              name  chi_indicator  \
# 53  glo-sub-054    male   25      Kelly Medina           True
# 19  glo-sub-020  female   29    Angela Johnson          False
# 83  glo-sub-084    male   20    Charles Morgan          False
# 95  glo-sub-096    male   39   Brandon Charles          False
# 47  glo-sub-048  female   51  Gabrielle Vaughn          False
#
#    ewallet_user_indicator  total_travel_distance
# 53                      Y           49803.383541
# 19                      N           50951.423568
# 83                      N           50126.644557
# 95                      N           44938.120470
# 47                      Y           46647.052089

# %%
sub = fake_subscribers.sample(1).sub_uid.item()
traj = get_sub_traj(sub, date, window, fake_transactions, fake_cellsites)
traj.head()
# Out:
#           txn_uid      sub_uid      cel_uid transaction_dt  transaction_hr  \
# 0   glo-txn-00628  glo-sub-005  glo-cel-028     2023-06-01               0
# 6   glo-txn-00629  glo-sub-005  glo-cel-026     2023-06-01               2
# 12  glo-txn-00630  glo-sub-005  glo-cel-033     2023-06-01               3
# 1   glo-txn-00631  glo-sub-005  glo-cel-028     2023-06-01               5
# 18  glo-txn-00632  glo-sub-005  glo-cel-015     2023-06-01               6
#
#                             coords
# 0    POINT (121.0485358 14.494388)
# 6   POINT (121.0480144 14.4988026)
# 12   POINT (121.050346 14.4970216)
# 1    POINT (121.0485358 14.494388)
# 18  POINT (121.0424143 14.4939573)

# %%
coords = traj.coords.tolist()

# %%
mean_lat = np.mean([shapely.wkt.loads(coord).y for coord in coords])
mean_lng = np.mean([shapely.wkt.loads(coord).x for coord in coords])
com = shapely.geometry.Point(mean_lng, mean_lat).wkt

# %%
print(mean_lat, mean_lng, com)
# Out:
# 14.512318452298851 121.05148582988507 POINT (121.05148582988507 14.512318452298851)

# %%
# compute for the distances from center of mass to each of the individual points
pt_pairs = list(zip(coords, [com]*len(coords))) # points-to-centerofmass
radius_of_gyration = np.sqrt(
    reduce(
        lambda a, b: a + b,
        list(map(lambda p: calc_haversine_distance(*p)**2, pt_pairs))
    ) / len(coords)
)

# %%
radius_of_gyration
# Out:
# 1123.9534687501643

# %%
def calc_radius_of_gyration(traj):
    
    coords = traj.coords.tolist()
    
    # compute for the center of mass
    mean_lat = np.mean([shapely.wkt.loads(coord).y for coord in coords])
    mean_lng = np.mean([shapely.wkt.loads(coord).x for coord in coords])
    com = shapely.geometry.Point(mean_lng, mean_lat).wkt
    
    # compute for the distances from CoM to individual points
    pt_pairs = list(zip(coords, [com]*len(coords)))
    radius_of_gyration = np.sqrt(
        reduce(
            lambda a, b: a + b,
            list(map(lambda p: calc_haversine_distance(*p)**2, pt_pairs))
        ) / len(coords)
    )
    return radius_of_gyration

# %%
radius_of_gyrations = []
for sub in scoring_base.sub_uid.tolist():
    traj = get_sub_traj(sub, date, window, fake_transactions, fake_cellsites)
    radius_of_gyration = calc_radius_of_gyration(traj)
    radius_of_gyrations.append(radius_of_gyration)

scoring_base["radius_of_gyration"] = radius_of_gyrations

# %%
scoring_base.sample(5)
# Out:
#         sub_uid  gender  age             name  chi_indicator  \
# 91  glo-sub-092  female   21    Valerie Short           True
# 55  glo-sub-056    male   25      Terry Gould           True
# 2   glo-sub-003    male   59      Steven King           True
# 29  glo-sub-030    male   36  Gerald Harrison          False
# 36  glo-sub-037    male   60   Jeffrey Church          False
#
#    ewallet_user_indicator  total_travel_distance  radius_of_gyration
# 91                      Y           66049.575613         1047.713163
# 55                      N           47942.556544          888.407175
# 2                       N           58861.062719         1723.534816
# 29                      N           57071.368021         1361.443078
# 36                      N           65522.669219         1302.643219

# %%
sub = fake_subscribers.sample(1).sub_uid.item()
traj = get_sub_traj(sub, date, window, fake_transactions, fake_cellsites)
traj.head()
# Out:
#           txn_uid      sub_uid      cel_uid transaction_dt  transaction_hr  \
# 0   glo-txn-06898  glo-sub-046  glo-cel-025     2023-06-01               5
# 3   glo-txn-06899  glo-sub-046  glo-cel-029     2023-06-01               6
# 8   glo-txn-06900  glo-sub-046  glo-cel-024     2023-06-01               7
# 11  glo-txn-06901  glo-sub-046  glo-cel-042     2023-06-01              10
# 13  glo-txn-06902  glo-sub-046  glo-cel-047     2023-06-01              13
#
#                             coords
# 0   POINT (121.0476753 14.4772396)
# 3   POINT (121.0485949 14.4716356)
# 8   POINT (121.0476021 14.4654285)
# 11  POINT (121.0548302 14.4679851)
# 13  POINT (121.0561115 14.4711265)

# %%
loc_hrs = traj[["cel_uid", "transaction_hr"]].values.tolist()
od_loc_hrs = list(zip(loc_hrs, loc_hrs[1:]))

# %%
cels = list(set(traj.cel_uid.tolist()))

# %%
loc_hr_counter = dict(zip(cels, [0]*len(cels))) # THIS IS THE HASHMAP
for od_loc_hr in od_loc_hrs:
    orig = od_loc_hr[0]
    dest = od_loc_hr[1]
    cel = orig[0]
    if dest[1] > orig[1]:
        time_elapsed = dest[1] - orig[1]
    elif dest[1] < orig[1]:
        # next time elapsed jumps to another day
        time_elapsed = 24 - abs(dest[1] - orig[1])
    loc_hr_counter[cel] = loc_hr_counter[cel] + time_elapsed #  # I UPDATED THE HASHMAP

# %%
loc_hr_counter
# Out:
# {'glo-cel-040': 46,
#  'glo-cel-050': 7,
#  'glo-cel-035': 4,
#  'glo-cel-054': 85,
#  'glo-cel-057': 13,
#  'glo-cel-029': 20,
#  'glo-cel-061': 4,
#  'glo-cel-056': 15,
#  'glo-cel-047': 1,
#  'glo-cel-052': 9,
#  'glo-cel-062': 1,
#  'glo-cel-043': 11,
#  'glo-cel-051': 19,
#  'glo-cel-038': 11,
#  'glo-cel-036': 41,
#  'glo-cel-042': 5,
#  'glo-cel-044': 7,
#  'glo-cel-041': 1,
#  'glo-cel-024': 5,
#  'glo-cel-063': 26,
#  'glo-cel-046': 23,
#  'glo-cel-039': 29,
#  'glo-cel-049': 37,
#  'glo-cel-055': 106,
#  'glo-cel-048': 7,
#  'glo-cel-025': 7,
#  'glo-cel-045': 65,
#  'glo-cel-067': 94,
#  'glo-cel-064': 15}

# %%
traj # sanity check
# Out:
#            txn_uid      sub_uid      cel_uid transaction_dt  transaction_hr  \
# 
# 140  glo-txn-07023  glo-sub-046  glo-cel-043     2023-06-25               5
# 136  glo-txn-07024  glo-sub-046  glo-cel-036     2023-06-25               6
# 118  glo-txn-07025  glo-sub-046  glo-cel-040     2023-06-25              10
# 142  glo-txn-07026  glo-sub-046  glo-cel-049     2023-06-25              16
# 143  glo-txn-07027  glo-sub-046  glo-cel-049     2023-06-26               5
# 147  glo-txn-07028  glo-sub-046  glo-cel-057     2023-06-26              11
# 151  glo-txn-07029  glo-sub-046  glo-cel-061     2023-06-26              14
# 132  glo-txn-07030  glo-sub-046  glo-cel-064     2023-06-26              18
# 128  glo-txn-07031  glo-sub-046  glo-cel-056     2023-06-26              21
# 129  glo-txn-07032  glo-sub-046  glo-cel-056     2023-06-27               5
# 123  glo-txn-07033  glo-sub-046  glo-cel-051     2023-06-27               7
# 144  glo-txn-07034  glo-sub-046  glo-cel-049     2023-06-27              11
# 148  glo-txn-07035  glo-sub-046  glo-cel-057     2023-06-27              19
# 141  glo-txn-07036  glo-sub-046  glo-cel-043     2023-06-27              20
# 149  glo-txn-07037  glo-sub-046  glo-cel-057     2023-06-27              23
# 150  glo-txn-07038  glo-sub-046  glo-cel-057     2023-06-28               5
# 145  glo-txn-07039  glo-sub-046  glo-cel-049     2023-06-28               8
# 124  glo-txn-07040  glo-sub-046  glo-cel-051     2023-06-28              15
# 146  glo-txn-07041  glo-sub-046  glo-cel-049     2023-06-28              16
# 119  glo-txn-07042  glo-sub-046  glo-cel-040     2023-06-28              19
# 120  glo-txn-07043  glo-sub-046  glo-cel-040     2023-06-29               5
# 137  glo-txn-07044  glo-sub-046  glo-cel-036     2023-06-29               8
# 138  glo-txn-07045  glo-sub-046  glo-cel-036     2023-06-30               5
# 121  glo-txn-07046  glo-sub-046  glo-cel-040     2023-06-30              12
# 112  glo-txn-07047  glo-sub-046  glo-cel-039     2023-06-30              17
# 125  glo-txn-07048  glo-sub-046  glo-cel-051     2023-06-30              20
# 113  glo-txn-07049  glo-sub-046  glo-cel-039     2023-06-30              23
#
#                              coords
# 0    POINT (121.0476753 14.4772396)
# 3    POINT (121.0485949 14.4716356)
# 8    POINT (121.0476021 14.4654285)
# 11   POINT (121.0548302 14.4679851)
# 13   POINT (121.0561115 14.4711265)
# 12   POINT (121.0548302 14.4679851)
# 9    POINT (121.0476021 14.4654285)
# 4    POINT (121.0485949 14.4716356)
# 1    POINT (121.0476753 14.4772396)
# 5    POINT (121.0485949 14.4716356)
# 6    POINT (121.0485949 14.4716356)
# 10   POINT (121.0476021 14.4654285)
# 7    POINT (121.0485949 14.4716356)
# 2    POINT (121.0476753 14.4772396)
# 14   POINT (121.0527667 14.4780747)
# 15   POINT (121.0527667 14.4780747)
# 16   POINT (121.0577886 14.4791915)
# 18   POINT (121.0568768 14.4764315)
# 17   POINT (121.0577886 14.4791915)
# 19   POINT (121.0565103 14.4833339)
# 21   POINT (121.0613845 14.4863308)
# 22   POINT (121.0613845 14.4863308)
# 20   POINT (121.0565103 14.4833339)
# 25   POINT (121.0611261 14.4830593)
# 23   POINT (121.0613845 14.4863308)
# 101  POINT (121.0547366 14.5005359)
# 102  POINT (121.0550896 14.5056935)
# 103  POINT (121.0550896 14.5056935)
# 104  POINT (121.0560984 14.5100246)
# 108  POINT (121.0536333 14.5133711)
# 114   POINT (121.054184 14.5167555)
# 109  POINT (121.0536333 14.5133711)
# 110  POINT (121.0536333 14.5133711)
# 122  POINT (121.0572633 14.5141269)
# 126  POINT (121.0591257 14.5116111)
# 130   POINT (121.0618839 14.512313)
# 131   POINT (121.0618839 14.512313)
# 127  POINT (121.0591257 14.5116111)
# 105  POINT (121.0560984 14.5100246)
# 133  POINT (121.0520115 14.5087523)
# 106  POINT (121.0560984 14.5100246)
# 107  POINT (121.0560984 14.5100246)
# 111  POINT (121.0536333 14.5133711)
# 115   POINT (121.054184 14.5167555)
# 116   POINT (121.054184 14.5167555)
# 134    POINT (121.052231 14.519476)
# 117   POINT (121.054184 14.5167555)
# 135    POINT (121.052231 14.519476)
# 139  POINT (121.0548721 14.5216456)
# 140  POINT (121.0548721 14.5216456)
# 136    POINT (121.052231 14.519476)
# 118   POINT (121.054184 14.5167555)
# 142  POINT (121.0568161 14.5177119)
# 143  POINT (121.0568161 14.5177119)
# 147   POINT (121.059168 14.5199865)
# 151   POINT (121.0609937 14.515681)
# 132   POINT (121.0618839 14.512313)
# 128  POINT (121.0591257 14.5116111)
# 129  POINT (121.0591257 14.5116111)
# 123  POINT (121.0572633 14.5141269)
# 144  POINT (121.0568161 14.5177119)
# 148   POINT (121.059168 14.5199865)
# 141  POINT (121.0548721 14.5216456)
# 149   POINT (121.059168 14.5199865)
# 150   POINT (121.059168 14.5199865)
# 145  POINT (121.0568161 14.5177119)
# 124  POINT (121.0572633 14.5141269)
# 146  POINT (121.0568161 14.5177119)
# 119   POINT (121.054184 14.5167555)
# 120   POINT (121.054184 14.5167555)
# 137    POINT (121.052231 14.519476)
# 138    POINT (121.052231 14.519476)
# 121   POINT (121.054184 14.5167555)
# 112  POINT (121.0536333 14.5133711)
# 125  POINT (121.0572633 14.5141269)
# 113  POINT (121.0536333 14.5133711)

# %%
proba_per_site = [hr_spent/sum(loc_hr_counter.values()) for hr_spent in loc_hr_counter.values()]

# %%
np.sum(proba_per_site)
# Out:
# 1.0

# %%
activity_entropy = reduce(lambda a, b: a + b, map(lambda p: p*np.log10(1/p), proba_per_site))
print(activity_entropy)

# TODO: add logbase2
# try float dtype
# Out:
# 1.2287708523253977

# %%
def calc_activity_entropy(traj):
    
    try:
    
        loc_hrs = traj[["cel_uid", "transaction_hr"]].values.tolist()
        od_loc_hrs = list(zip(loc_hrs, loc_hrs[1:]))    
        cels = list(set(traj.cel_uid.tolist()))

        loc_hr_counter = dict(zip(cels, [0]*len(cels)))
        for od_loc_hr in od_loc_hrs:
            orig = od_loc_hr[0]
            dest = od_loc_hr[1]
            cel = orig[0]
            if dest[1] > orig[1]:
                time_elapsed = dest[1] - orig[1]
            elif dest[1] < orig[1]:
                # next time elapsed jumps to another day
                time_elapsed = 24 - abs(dest[1] - orig[1])
            loc_hr_counter[cel] = loc_hr_counter[cel] + time_elapsed

        # time spent on a single site vs time spent on all sites
        proba_per_site = [hr_spent/sum(loc_hr_counter.values()) for hr_spent in loc_hr_counter.values()]

        # sum(p * log(1/p)) where p is the proba for a single site
        activity_entropy = reduce(lambda a, b: a + b, map(lambda p: p*np.log10(1/p), proba_per_site))
    
        return activity_entropy
    
    except:
        
        return None

# %%
activity_entropys = []
for sub in scoring_base.sub_uid.tolist():
    traj = get_sub_traj(sub, date, window, fake_transactions, fake_cellsites)
    activity_entropy = calc_activity_entropy(traj)
    activity_entropys.append(activity_entropy)

scoring_base["activity_entropy"] = activity_entropys

# %%
scoring_base.sample(5)
# Out:
#         sub_uid  gender  age             name  chi_indicator  \
# 4   glo-sub-005    male   41  Stephen Barrett          False
# 51  glo-sub-052  female   60   Victoria Davis           True
# 73  glo-sub-074    male   59   Austin Shelton          False
# 5   glo-sub-006    male   30    Ronald Lester          False
# 12  glo-sub-013  female   70     Sharon Hogan          False
#
#    ewallet_user_indicator  total_travel_distance  radius_of_gyration  \
# 4                       Y           59372.713510         1123.953469
# 51                      N           63698.991406         1255.827815
# 73                      Y           54565.860869          437.301958
# 5                       N           49404.280524          750.467398
# 12                      Y           62534.631257          583.661584
#
#     activity_entropy
# 4           1.404239
# 51          1.274839
# 73          0.763808
# 5           1.204405
# 12          0.884228

# %%
scoring_base.total_travel_distance.describe().iloc[1:]
# Out:
# mean    55157.115296
# std      7521.101911
# min     39499.305833
# 25%     49938.614556
# 50%     54628.834575
# 75%     59577.137135
# max     72655.926457
# Name: total_travel_distance, dtype: float64

# %%
scoring_base.radius_of_gyration.describe().iloc[1:]
# Out:
# mean    1184.597493
# std      373.011130
# min      437.301958
# 25%      971.721602
# 50%     1150.023233
# 75%     1354.398274
# max     2959.760407
# Name: radius_of_gyration, dtype: float64

# %%
scoring_base.activity_entropy.describe().iloc[1:]
# Out:
# mean    1.255673
# std     0.163772
# min     0.763808
# 25%     1.148662
# 50%     1.283184
# 75%     1.379630
# max     1.526844
# Name: activity_entropy, dtype: float64

# %%
sub = fake_subscribers.sample(1).sub_uid.item()
traj = get_sub_traj(sub, date, window, fake_transactions, fake_cellsites)

# %%
traj.head()
# Out:
#           txn_uid      sub_uid      cel_uid transaction_dt  transaction_hr  \
# 0   glo-txn-00001  glo-sub-001  glo-cel-082     2023-06-01               3
# 5   glo-txn-00002  glo-sub-001  glo-cel-086     2023-06-01              15
# 11  glo-txn-00003  glo-sub-001  glo-cel-084     2023-06-01              20
# 6   glo-txn-00004  glo-sub-001  glo-cel-086     2023-06-01              21
# 12  glo-txn-00005  glo-sub-001  glo-cel-084     2023-06-01              23
#
#                             coords
# 0   POINT (121.0732848 14.5244576)
# 5    POINT (121.0750697 14.521689)
# 11  POINT (121.0735688 14.5181671)
# 6    POINT (121.0750697 14.521689)
# 12  POINT (121.0735688 14.5181671)

# %%
calc_activity_entropy(traj)
# Out:
# 1.3153954278432864

# %%
calc_radius_of_gyration(traj)
# Out:
# 1219.4454644797752

# %%
calc_total_travel_distance(traj)
# Out:
# 55610.046496628296

# %%
def get_route_fig(r):
    fig, ax = plt.subplots(1, 1)
    gpd.GeoSeries(r).plot(ax=ax, linewidth=5, zorder=1)
    orig = shapely.geometry.Point([r.xy[0][0], r.xy[1][0]])
    dest = shapely.geometry.Point([r.xy[0][-1], r.xy[1][-1]])
    gpd.GeoSeries(orig).plot(ax=ax, color="red", markersize=250, zorder=2, alpha=0.8)
    gpd.GeoSeries(dest).plot(ax=ax, color="green", markersize=250, zorder=2, alpha=0.8)
    plt.axis("off")
    ax.ticklabel_format(useOffset=False)
    plt.close()
    return fig

import os
import shapely
import geopandas as gpd
import matplotlib.pyplot as plt
from PIL import Image
import shutil

# %%
d
# Out:
#              txn_uid      sub_uid      cel_uid transaction_dt  transaction_hr
# 0      glo-txn-00001  glo-sub-001  glo-cel-082     2023-06-01               3
# 1      glo-txn-00002  glo-sub-001  glo-cel-086     2023-06-01              15
# 2      glo-txn-00003  glo-sub-001  glo-cel-084     2023-06-01              20
# 3      glo-txn-00004  glo-sub-001  glo-cel-086     2023-06-01              21
# 4      glo-txn-00005  glo-sub-001  glo-cel-084     2023-06-01              23
# ...              ...          ...          ...            ...             ...
# 15085  glo-txn-15086  glo-sub-100  glo-cel-040     2023-06-29              12
# 15086  glo-txn-15087  glo-sub-100  glo-cel-040     2023-06-30               0
# 15087  glo-txn-15088  glo-sub-100  glo-cel-049     2023-06-30               3
# 15088  glo-txn-15089  glo-sub-100  glo-cel-057     2023-06-30              12
# 15089  glo-txn-15090  glo-sub-100  glo-cel-049     2023-06-30              18
#
# [15090 rows x 5 columns]

# %%
# day in a life of a sub
d = fake_transactions.copy()
sample_sub = d.sample(1).sub_uid.item()
d = d.loc[d.sub_uid==sample_sub]
days = d.transaction_dt.unique().tolist()
route_figs = []

# %%
for sample_day in days:
    sites = fake_transactions\
        .loc[fake_transactions.sub_uid==sample_sub]\
        .loc[fake_transactions.transaction_dt==sample_day]\
        .cel_uid.tolist()
    points = list(map(lambda z: convert_cel_to_point(z, fake_cellsites), sites))
    r = shapely.geometry.LineString(points)
    route_figs.append(get_route_fig(r))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[66], line 6
#       1 for sample_day in days:
#       2     sites = fake_transactions\
#       3         .loc[fake_transactions.sub_uid==sample_sub]\
#       4         .loc[fake_transactions.transaction_dt==sample_day]\
#       5         .cel_uid.tolist()
# ----> 6     points = list(map(lambda z: convert_cel_to_point(z, fake_cellsites), sites))
#       7     r = shapely.geometry.LineString(points)
#       8     route_figs.append(get_route_fig(r))
#
# Cell In[66], line 6, in <lambda>(z)
#       1 for sample_day in days:
#       2     sites = fake_transactions\
#       3         .loc[fake_transactions.sub_uid==sample_sub]\
#       4         .loc[fake_transactions.transaction_dt==sample_day]\
#       5         .cel_uid.tolist()
# ----> 6     points = list(map(lambda z: convert_cel_to_point(z, fake_cellsites), sites))
#       7     r = shapely.geometry.LineString(points)
#       8     route_figs.append(get_route_fig(r))
#
# File ~\Desktop\sds4gdsp\sds4gdsp\processor.py:21, in convert_cel_to_point(cel_id, ref)
#      19 def convert_cel_to_point(cel_id: str, ref: pd.DataFrame):
#      20     """Convert cellsite to shapely point."""
# ---> 21     coord = ref.loc[ref.uid==cel_id].coords.item()
#      22     point = loads(coord)
#      23     return point
#
# File ~\Anaconda3\envs\gdsenv3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'uid'

# %%
os.mkdir("../sample/")

for idx, fig in enumerate(route_figs):
    fname = "../sample/{}_tmp.jpg".format(idx+1)
    fig.savefig(fname)
    
imgs = load_images("../sample")
plot_images(imgs)
shutil.rmtree("../sample")
